# %%
from pyspark import SparkConf, SparkContext

# Initialize Spark context
conf = SparkConf().setAppName("CreateRDD").setMaster("local[*]")
sc = SparkContext(conf=conf)

# Define the data
data = [
    {
        "full_name": "Koppala Tharun",
        "date_of_birth": "16/07/2001",
        "phone_number": "+91 8019839983",
        "email_address": "tharunkoppala1717@gmail.com",
        "father_name": "Koppala Sudhakar",
        "father_date_of_birth": "02/03/1976",
        "mother_name": "Koppala Subbalakshmi",
        "mother_date_of_birth": "24/09/1978",
        "full_address": "Kothacheruvu Village, Perimidi Post (524421), Ozili Mandal, SPSR Nellore District, Andhra Pradesh."
    },
    {
        "full_name": "Kaku Rajendra",
        "date_of_birth": "21/05/1998",
        "phone_number": "+91 6302935224",
        "email_address": "rajendrareddykaku2@gmail.com",
        "father_name": "Kaku Janardhan Reddy",
        "father_date_of_birth": None,  # Missing data
        "mother_name": "Kaku Jyothi",
        "mother_date_of_birth": None,  # Missing data
        "full_address": "Athalapalem Village, Yakasiri Post (524126), Nayudupeta Mandal, SPSR Nellore District, Andhra Pradesh."
    },
    {
        "full_name": "Korasikha Lakshmi Narayana",
        "date_of_birth": "21/11/1999",
        "phone_number": "+91 9640794667",
        "email_address": "lakshmi112199@gmail.com",
        "father_name": "Korasikha Venkata Rama Krishna",
        "father_date_of_birth": None,  # Missing data
        "mother_name": "Korasikha Vara Lakshmi",
        "mother_date_of_birth": None,  # Missing data
        "full_address": "Bondada Peta Village, Door No-5-127, Kalla Mandal, West Godavari District, Andhra Pradesh."
    }
]

# Create RDD from the data
rdd = sc.parallelize(data)

# Print the RDD
print(rdd.collect())

# Stop the Spark context
sc.stop()
# Out:
# [{'full_name': 'Koppala Tharun', 'date_of_birth': '16/07/2001', 'phone_number': '+91 8019839983', 'email_address': 'tharunkoppala1717@gmail.com', 'father_name': 'Koppala Sudhakar', 'father_date_of_birth': '02/03/1976', 'mother_name': 'Koppala Subbalakshmi', 'mother_date_of_birth': '24/09/1978', 'full_address': 'Kothacheruvu Village, Perimidi Post (524421), Ozili Mandal, SPSR Nellore District, Andhra Pradesh.'}, {'full_name': 'Kaku Rajendra', 'date_of_birth': '21/05/1998', 'phone_number': '+91 6302935224', 'email_address': 'rajendrareddykaku2@gmail.com', 'father_name': 'Kaku Janardhan Reddy', 'father_date_of_birth': None, 'mother_name': 'Kaku Jyothi', 'mother_date_of_birth': None, 'full_address': 'Athalapalem Village, Yakasiri Post (524126), Nayudupeta Mandal, SPSR Nellore District, Andhra Pradesh.'}, {'full_name': 'Korasikha Lakshmi Narayana', 'date_of_birth': '21/11/1999', 'phone_number': '+91 9640794667', 'email_address': 'lakshmi112199@gmail.com', 'father_name': 'Korasikha Venkata
# ...

# %%
from pyspark.sql import SparkSession

# Create a Spark session
spark = SparkSession.builder \
    .appName("CreateDataFrame") \
    .master("local[*]") \
    .getOrCreate()

# Define the data
data = [
    {
        "full_name": "Koppala Tharun",
        "date_of_birth": "16/07/2001",
        "phone_number": "+91 8019839983",
        "email_address": "tharunkoppala1717@gmail.com",
        "father_name": "Koppala Sudhakar",
        "father_date_of_birth": "02/03/1976",
        "mother_name": "Koppala Subbalakshmi",
        "mother_date_of_birth": "24/09/1978",
        "full_address": "Kothacheruvu Village, Perimidi Post (524421), Ozili Mandal, SPSR Nellore District, Andhra Pradesh."
    },
    {
        "full_name": "Kaku Rajendra",
        "date_of_birth": "21/05/1998",
        "phone_number": "+91 6302935224",
        "email_address": "rajendrareddykaku2@gmail.com",
        "father_name": "Kaku Janardhan Reddy",
        "father_date_of_birth": "24/03/1968",
        "mother_name": "Kaku Jyothi",
        "mother_date_of_birth": "01/07/1978",
        "full_address": "Athalapalem Village, Yakasiri Post (524126), Nayudupeta Mandal, SPSR Nellore District, Andhra Pradesh."
    },
    {
        "full_name": "Korasikha Lakshmi Narayana",
        "date_of_birth": "21/11/1999",
        "phone_number": "+91 9640794667",
        "email_address": "lakshmi112199@gmail.com",
        "father_name": "Korasikha Venkata Rama Krishna",
        "father_date_of_birth": "14/05/1976",
        "mother_name": "Korasikha Vara Lakshmi",
        "mother_date_of_birth": "22/04/1980",
        "full_address": "Bondada Peta Village, Door No-5-127, Kalla Mandal, West Godavari District, Andhra Pradesh."
    }
]

# Create DataFrame from the data
df = spark.createDataFrame(data)

# Define the path to save the Parquet file
parquet_path = r"C:\Users\tharu\Project_Git_Push\New_Tharun_Branch\Tharun_Projects\Testing\details.parquet"

# Save the DataFrame as a Parquet file
df.write.mode("overwrite").parquet(parquet_path)

# Stop the Spark session
spark.stop()

print(f"DataFrame saved as a Parquet file to {parquet_path}")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[2], line 53
#      50 parquet_path = r"C:\Users\tharu\Project_Git_Push\New_Tharun_Branch\Tharun_Projects\Testing\details.parquet"
#      52 # Save the DataFrame as a Parquet file
# ---> 53 df.write.mode("overwrite").parquet(parquet_path)
#      55 # Stop the Spark session
#      56 spark.stop()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyspark\sql\readwriter.py:1721, in DataFrameWriter.parquet(self, path, mode, partitionBy, compression)
#    1719     self.partitionBy(partitionBy)
#    1720 self._set_opts(compression=compression)
# -> 1721 self._jwrite.parquet(path)
#
# ...
