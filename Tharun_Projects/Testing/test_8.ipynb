# %%
import pandas as pd

mydataset = {
  'cars': ["BMW", "Volvo", "Ford", "RangeRover", "Scoda", "Jeep"],
  'passings': [3, 7, 2, 5, 8, 3],
  'Owner_Name':["Justin", "Sam", "Yogi", "Kranthi", "Leo", "Adam"]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#          cars  passings Owner_Name
# 0         BMW         3     Justin
# 1       Volvo         7        Sam
# 2        Ford         2       Yogi
# 3  RangeRover         5    Kranthi
# 4       Scoda         8        Leo
# 5        Jeep         3       Adam

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.1.4

# %%
import pandas as pd

a = [1, 7, 2, 4, 6, 9, 3, 2, 1]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# 3    4
# 4    6
# 5    9
# 6    3
# 7    2
# 8    1
# dtype: int64

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = [2 ,4, 5])

print(myvar)
# Out:
# 2    1
# 4    7
# 5    2
# dtype: int64

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#refer to the row index:
print(myvar.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
#refer to the row index:
print(myvar.loc[[0, 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
import pandas as pd

df = pd.read_csv('C:/Users/tharu/CSV_Data.csv')

print(df)
# Out:
#     DEPTNO   DNAME      LOCATION
# 0       30   SMITH      NEW YORK
# 1       20   ALLEN       CHICAGO
# 2       20     SAM   LOS ANGELES
# 3       30  MARTIN        DALLAS
# 4       10   BLACK  SAN FRANSICO
# 5       30    KING       CHICAGO
# 6       20  TURNER      NEW YORK
# 7       30   SCOTT        DALLAS
# 8       10   ADAMS       CHICAGO
# 9       10    FORD      NEW YORK
# 10      20  MILLER   LOS ANGELES

# %%
print(df.to_string())
# Out:
#     DEPTNO   DNAME      LOCATION
# 0       30   SMITH      NEW YORK
# 1       20   ALLEN       CHICAGO
# 2       20     SAM   LOS ANGELES
# 3       30  MARTIN        DALLAS
# 4       10   BLACK  SAN FRANSICO
# 5       30    KING       CHICAGO
# 6       20  TURNER      NEW YORK
# 7       30   SCOTT        DALLAS
# 8       10   ADAMS       CHICAGO
# 9       10    FORD      NEW YORK
# 10      20  MILLER   LOS ANGELES

# %%
import pandas as pd

pd.options.display.max_rows = 9999

df = pd.read_csv("C:/Users/tharu/Downloads/data.csv")

print(df.tail())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
print(df.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %%
new_df = df.dropna()

print(new_df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
x = df["Calories"].mean()

df["Calories"].fillna(x, inplace = True)

# %%
import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
print(df.tail())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300
